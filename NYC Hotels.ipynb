# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner


# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting map library

print('Folium installed')
print('All Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          92 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.21.0-py_0
#
#
#
# Downloading and Extracting Packages
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     chardet-3.0.4              |py36h9f0ad1d_1006         188 KB  conda-forge
#     cryptography-2.8           |   py36h45558ae_2         628 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     jinja2-2.11.2              |     pyh9f0ad1d_0          93 KB  conda-forge
#     pandas-1.0.3               |   py36h830a2c2_0        11.1 MB  conda-forge
#     pysocks-1.7.1              |   py36h9f0ad1d_1          27 KB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     urllib3-1.25.8             |   py36h9f0ad1d_1         160 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        12.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-19.3.0-py_0
#   branca             conda-forge/noarch::branca-0.4.0-py_0
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9f0ad1d_1006
#   cryptography       conda-forge/linux-64::cryptography-2.8-py36h45558ae_2
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36h9f0ad1d_1001
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.9-py_1
#   importlib-metadata conda-forge/linux-64::importlib-metadata-1.6.0-py36h9f0ad1d_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-1.6.0-0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/linux-64::jsonschema-3.2.0-py36h9f0ad1d_1
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36h8c4c3a4_1
#   pandas             conda-forge/linux-64::pandas-1.0.3-py36h830a2c2_0
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.16.0-py36h8c4c3a4_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9f0ad1d_1
#   pytz               conda-forge/noarch::pytz-2019.3-py_0
#   requests           conda-forge/noarch::requests-2.23.0-pyh8c360ce_2
#   toolz              conda-forge/noarch::toolz-0.10.0-py_0
#   urllib3            conda-forge/linux-64::urllib3-1.25.8-py36h9f0ad1d_1
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#   zipp               conda-forge/noarch::zipp-3.1.0-py_0
#
#
#
# Downloading and Extracting Packages
# jinja2-2.11.2        | 93 KB     | ##################################### | 100%
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# cryptography-2.8     | 628 KB    | ##################################### | 100%
# toolz-0.10.0         | 46 KB     | ##################################### | 100%
# pandas-1.0.3         | 11.1 MB   | ##################################### | 100%
# chardet-3.0.4        | 188 KB    | ##################################### | 100%
# urllib3-1.25.8       | 160 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# All Libraries imported.

# %%
CLIENT_ID='NSWC0SRL1NVQY551AP3I0RAQPIFKF3PXC3XBYGT1DEGC0CJM'
CLIENT_SECRET='1EDCF3ZSYUHAO2A03AOK0QEIIWM1UGSL3XBSYKTV4LYHAWV2'
latitude=40.7590
longitude=-73.9845
VERSION=20200401
search_query = 'hotels'
radius = 10000 # 10 KM
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius)
result_hotels = requests.get(url).json()
result_hotels
# Out:
# {'meta': {'code': 200, 'requestId': '5e9708f071c428001bc7bed4'},
#  'response': {'venues': [{'id': '4cadd6b9d1f8b60cf41d72c6',
#     'name': 'Leading Hotels of the World',
#     'location': {'address': '99 Park Ave',
#      'crossStreet': '40th St',
#      'lat': 40.750323,
#      'lng': -73.978408,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.750323,
#        'lng': -73.978408},
#       {'label': '?', 'lat': 40.750435, 'lng': -73.978604}],
#      'distance': 1094,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['99 Park Ave (40th St)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '5147898ce4b02dd3371672de',
#     'name': 'Loews Hotels & Resorts',
#     'location': {'address': '667 Madison Ave',
#      'lat': 40.76451788,
#      'lng': -73.97021373,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76451788,
#        'lng': -73.97021373}],
#      'distance': 1352,
#      'postalCode': '10065',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['667 Madison Ave',
#       'New York, NY 10065',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '5915de0bda5ede1d81c935b1',
#     'name': 'Hotels Cheap Booking Worldwide | أرخص حجوزات الفنادق حول العالم (Hotels Cheap Booking Worldwide)',
#     'location': {'address': 'E65th St',
#      'crossStreet': 'E65th St',
#      'lat': 40.766867238017305,
#      'lng': -73.96724581718445,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.766867238017305,
#        'lng': -73.96724581718445}],
#      'distance': 1698,
#      'postalCode': '10065',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['E65th St (E65th St)',
#       'New York, NY 10065',
#       'United States']},
#     'categories': [{'id': '4f04b08c2fb6e1c99f3db0bd',
#       'name': 'Travel Agency',
#       'pluralName': 'Travel Agencies',
#       'shortName': 'Travel Agency',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/travelagency_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '51349950e4b07cce559b7ccf',
#     'name': 'Starwood Hotels Global Offices',
#     'location': {'lat': 40.76023595473447,
#      'lng': -73.98112335499499,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76023595473447,
#        'lng': -73.98112335499499}],
#      'distance': 316,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY 10019', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '5690195e498edb833ddabfac',
#     'name': 'Triumph Hotels',
#     'location': {'address': '1633 Broadway',
#      'lat': 40.7623254,
#      'lng': -73.98468752,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7623254,
#        'lng': -73.98468752},
#       {'label': '?', 'lat': 40.761921, 'lng': -73.984263}],
#      'distance': 370,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1633 Broadway',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '5032885091d4c4b30a586d66',
#       'name': 'Real Estate Office',
#       'pluralName': 'Real Estate Offices',
#       'shortName': 'Real Estate',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/realestate_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '579017919'},
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '4e56ae3eb993a739822887b4',
#     'name': 'Starwood Hotels NYC Metro Market Office',
#     'location': {'lat': 40.762447766855274,
#      'lng': -73.98105835827147,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.762447766855274,
#        'lng': -73.98105835827147}],
#      'distance': 481,
#      'cc': 'US',
#      'state': 'New York',
#      'country': 'United States',
#      'formattedAddress': ['New York', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '4e00b2ea1f6ef39c2940bcbb',
#     'name': 'Compass Hotels Club',
#     'location': {'address': '40 W 45th St',
#      'lat': 40.758463,
#      'lng': -73.979025,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.758463,
#        'lng': -73.979025}],
#      'distance': 465,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['40 W 45th St',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '4c5062532a73c928161e6dd2',
#     'name': 'Orient Express Hotels',
#     'location': {'address': '1114 Avenue of the Americas Fl 38',
#      'crossStreet': '42nd St',
#      'lat': 40.75476586818695,
#      'lng': -73.98321032524109,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75476586818695,
#        'lng': -73.98321032524109}],
#      'distance': 483,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1114 Avenue of the Americas Fl 38 (42nd St)',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '4c20bb264d4a20a1a7259b70',
#     'name': 'Starwood Hotels Global Sales Office',
#     'location': {'address': '650 5th Ave',
#      'lat': 40.759982050597806,
#      'lng': -73.97681501726309,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.759982050597806,
#        'lng': -73.97681501726309}],
#      'distance': 657,
#      'postalCode': '10019',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['650 5th Ave',
#       'New York, NY 10019',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '550c5e1b498ec8c459b165c6',
#     'name': 'Le Soleil Executive Hotels',
#     'location': {'address': '38 W 36th St',
#      'lat': 40.75040662233482,
#      'lng': -73.98543953502728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75040662233482,
#        'lng': -73.98543953502728},
#       {'label': '?', 'lat': 40.750342, 'lng': -73.985317}],
#      'distance': 959,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['38 W 36th St',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '512654d8e4b0c83f4d8a92b0',
#     'name': 'Hyatt Hotels Corporation Global Sales',
#     'location': {'address': '3 E 41st St',
#      'crossStreet': 'Madison and 5th',
#      'lat': 40.752648136178884,
#      'lng': -73.98092248281702,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.752648136178884,
#        'lng': -73.98092248281702}],
#      'distance': 768,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['3 E 41st St (Madison and 5th)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '4da7a1b8a86e68edb7cc3419',
#     'name': 'Apple Core Hotels',
#     'location': {'address': '15 W 39th St, 2nd Floor',
#      'lat': 40.752297999999996,
#      'lng': -73.983416,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.752297999999996,
#        'lng': -73.983416},
#       {'label': '?', 'lat': 40.752189, 'lng': -73.983494}],
#      'distance': 751,
#      'postalCode': '10018',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['15 W 39th St, 2nd Floor',
#       'New York, NY 10018',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '4c4df46792b6a593beb7216f',
#     'name': 'CARINO Hotels & Resorts Worldwide HQ',
#     'location': {'address': '230 Park Ave Rm 1000',
#      'crossStreet': '(Bet 45th and 46th Streets on Park Ave)',
#      'lat': 40.755237767160175,
#      'lng': -73.9764688057595,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.755237767160175,
#        'lng': -73.9764688057595}],
#      'distance': 796,
#      'postalCode': '10169',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['230 Park Ave Rm 1000 ((Bet 45th and 46th Streets on Park Ave))',
#       'New York, NY 10169',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '5841facedb6cd606fead9b04',
#     'name': 'Even Hotels New York - Midtown East',
#     'location': {'address': '221 E 44th St',
#      'crossStreet': 'btwn 3rd and 2nd Ave',
#      'lat': 40.7518354,
#      'lng': -73.9723757,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.7518354,
#        'lng': -73.9723757}],
#      'distance': 1296,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['221 E 44th St (btwn 3rd and 2nd Ave)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '5061c80ee4b08374aa9b8291',
#     'name': 'Leading Hotels of the World',
#     'location': {'address': '485 Lexington Ave',
#      'crossStreet': '47th St',
#      'lat': 40.75386722988113,
#      'lng': -73.97367534054774,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75386722988113,
#        'lng': -73.97367534054774},
#       {'label': '?', 'lat': 40.75433, 'lng': -73.973804}],
#      'distance': 1076,
#      'postalCode': '10017',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['485 Lexington Ave (47th St)',
#       'New York, NY 10017',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1f6931735',
#       'name': 'General Travel',
#       'pluralName': 'General Travel',
#       'shortName': 'Travel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '4f0ee72ee4b0575169a8563a',
#     'name': 'Orient Express Hotels, Ltd. HQ',
#     'location': {'address': '555 Madison Ave',
#      'crossStreet': 'E55th Street',
#      'lat': 40.76133983707058,
#      'lng': -73.97283002914752,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.76133983707058,
#        'lng': -73.97283002914752}],
#      'distance': 1017,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['555 Madison Ave (E55th Street)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '52f27359498e7163b8ef6279',
#     'name': 'Loews Hotels',
#     'location': {'address': '667 Madison Ave',
#      'crossStreet': '61st',
#      'lat': 40.75457116813021,
#      'lng': -73.9360596116731,
#      'distance': 4114,
#      'postalCode': '10065',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['667 Madison Ave (61st)',
#       'New York, NY 10065',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '4c93981c533aa0933254b745',
#     'name': 'Concorde Hotels & Resorts Corporate Office',
#     'location': {'address': '1 Penn Plz',
#      'crossStreet': 'btw Fashion & 8th',
#      'lat': 40.75090427981508,
#      'lng': -73.99233168961038,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75090427981508,
#        'lng': -73.99233168961038}],
#      'distance': 1117,
#      'postalCode': '10119',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['1 Penn Plz (btw Fashion & 8th)',
#       'New York, NY 10119',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '5afde00d029a55002c04aa94',
#     'name': 'Lowe’s Hotels',
#     'location': {'address': '655 Madison Ave',
#      'lat': 40.762854,
#      'lng': -73.970931,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.762854,
#        'lng': -73.970931}],
#      'distance': 1221,
#      'postalCode': '10065',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['655 Madison Ave',
#       'New York, NY 10065',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '4d4711197e2e5481b9127a8f',
#     'name': 'Grandlife Hotels',
#     'location': {'address': '310 W Broadway',
#      'lat': 40.72203190438143,
#      'lng': -74.0046698566156,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.72203190438143,
#        'lng': -74.0046698566156}],
#      'distance': 4453,
#      'postalCode': '10013',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['310 W Broadway',
#       'New York, NY 10013',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '4ca39f685720b1f7515633ef',
#     'name': "The Pod Hotel's Rooftop Terrace",
#     'location': {'address': '230 E 51st St',
#      'crossStreet': 'Between 2nd & 3rd',
#      'lat': 40.75548117470931,
#      'lng': -73.96934015895559,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75548117470931,
#        'lng': -73.96934015895559}],
#      'distance': 1336,
#      'postalCode': '10022',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['230 E 51st St (Between 2nd & 3rd)',
#       'New York, NY 10022',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d133951735',
#       'name': 'Roof Deck',
#       'pluralName': 'Roof Decks',
#       'shortName': 'Roof Deck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_roofdeck_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '528512c611d20598768a6d4c',
#     'name': 'Accor Hotels N.A. HQ',
#     'location': {'address': '3 Park Ave',
#      'crossStreet': 'E 34 St.',
#      'lat': 40.74693298339844,
#      'lng': -73.98133850097656,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.74693298339844,
#        'lng': -73.98133850097656}],
#      'distance': 1369,
#      'postalCode': '10016',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['3 Park Ave (E 34 St.)',
#       'New York, NY 10016',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '4a0215c6f964a5202a711fe3',
#     'name': 'Millennium Broadway Hotel',
#     'location': {'address': '145 W 44th St',
#      'crossStreet': 'at Broadway',
#      'lat': 40.757073,
#      'lng': -73.9848,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.757073,
#        'lng': -73.9848}],
#      'distance': 215,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['145 W 44th St (at Broadway)',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '58446022'},
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '50637e02e4b06a6415f2af29',
#     'name': 'D Pet Hotels',
#     'location': {'address': '104 W 27th St',
#      'lat': 40.745629531112385,
#      'lng': -73.99143422143813,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.745629531112385,
#        'lng': -73.99143422143813}],
#      'distance': 1599,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['104 W 27th St',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '5032897c91d4c4b30a586d69',
#       'name': 'Pet Service',
#       'pluralName': 'Pet Services',
#       'shortName': 'Pet Service',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '43765909'},
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '51d5e28a498e14890713c77b',
#     'name': 'D Pet Hotels Chelsea',
#     'location': {'address': '104 W 27th St',
#      'lat': 40.745545,
#      'lng': -73.9915655,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.745545,
#        'lng': -73.9915655}],
#      'distance': 1611,
#      'postalCode': '10001',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['104 W 27th St',
#       'New York, NY 10001',
#       'United States']},
#     'categories': [{'id': '5032897c91d4c4b30a586d69',
#       'name': 'Pet Service',
#       'pluralName': 'Pet Services',
#       'shortName': 'Pet Service',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '4b4e71caf964a520f8ed26e3',
#     'name': 'Sofitel New York',
#     'location': {'address': '45 W 44th St',
#      'crossStreet': 'at 6th Ave',
#      'lat': 40.75578722233005,
#      'lng': -73.98176215591775,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.75578722233005,
#        'lng': -73.98176215591775},
#       {'label': '?', 'lat': 40.755676, 'lng': -73.981838}],
#      'distance': 425,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['45 W 44th St (at 6th Ave)',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '563582647'},
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '4b4ba81df964a5200ba326e3',
#     'name': 'Hotel St James',
#     'location': {'address': '109 W 45th St',
#      'crossStreet': 'btw 7th Ave & 6th Ave',
#      'lat': 40.757038476984555,
#      'lng': -73.9833259473536,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.757038476984555,
#        'lng': -73.9833259473536}],
#      'distance': 239,
#      'postalCode': '10036',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['109 W 45th St (btw 7th Ave & 6th Ave)',
#       'New York, NY 10036',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '524f040e11d25521010a001a',
#     'name': 'Hotels Curated NYC',
#     'location': {'lat': 40.739395,
#      'lng': -74.006986,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.739395,
#        'lng': -74.006986}],
#      'distance': 2891,
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['New York, NY', 'United States']},
#     'categories': [{'id': '507c8c4091d498d9fc8c67a9',
#       'name': 'Public Art',
#       'pluralName': 'Public Art',
#       'shortName': 'Public Art',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '4c23c942a852c9288510e26c',
#     'name': 'Hotels AB',
#     'location': {'address': '23 E 4th St',
#      'crossStreet': 'Lafayette',
#      'lat': 40.727819000000004,
#      'lng': -73.992573,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.727819000000004,
#        'lng': -73.992573},
#       {'label': '?', 'lat': 40.727725, 'lng': -73.992666}],
#      'distance': 3537,
#      'postalCode': '10003',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['23 E 4th St (Lafayette)',
#       'New York, NY 10003',
#       'United States']},
#     'categories': [],
#     'referralId': 'v-1586956785',
#     'hasPerk': False},
#    {'id': '504f6f44e4b06a753d408617',
#     'name': 'Faena Hotels',
#     'location': {'address': '420 W 14th St',
#      'lat': 40.741636026913795,
#      'lng': -74.006626674244,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 40.741636026913795,
#        'lng': -74.006626674244}],
#      'distance': 2686,
#      'postalCode': '10014',
#      'cc': 'US',
#      'city': 'New York',
#      'state': 'NY',
#      'country': 'United States',
#      'formattedAddress': ['420 W 14th St',
#       'New York, NY 10014',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1586956785',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to hotel
hotels = result_hotels['response']['venues']

# tranform hotels into a dataframe
df_hotels = json_normalize(hotels)
df_hotels.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id  \
# 0  4cadd6b9d1f8b60cf41d72c6
# 1  5147898ce4b02dd3371672de
# 2  5915de0bda5ede1d81c935b1
# 3  51349950e4b07cce559b7ccf
# 4  5690195e498edb833ddabfac
#
#                                                 name  \
# 0                        Leading Hotels of the World
# 1                             Loews Hotels & Resorts
# 2  Hotels Cheap Booking Worldwide | أرخص حجوزات ا...
# 3                     Starwood Hotels Global Offices
# 4                                     Triumph Hotels
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1586956785    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1586956785    False
# 2  [{'id': '4f04b08c2fb6e1c99f3db0bd', 'name': 'T...  v-1586956785    False
# 3  [{'id': '4bf58dd8d48988d130941735', 'name': 'B...  v-1586956785    False
# 4  [{'id': '5032885091d4c4b30a586d66', 'name': 'R...  v-1586956785    False
#
#   location.address location.crossStreet  location.lat  location.lng  \
# 0      99 Park Ave              40th St     40.750323    -73.978408
# 1  667 Madison Ave                  NaN     40.764518    -73.970214
# 2         E65th St             E65th St     40.766867    -73.967246
# 3              NaN                  NaN     40.760236    -73.981123
# 4    1633 Broadway                  NaN     40.762325    -73.984688
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.750323, 'lng':...               1094
# 1  [{'label': 'display', 'lat': 40.76451788, 'lng...               1352
# 2  [{'label': 'display', 'lat': 40.76686723801730...               1698
# 3  [{'label': 'display', 'lat': 40.76023595473447...                316
# 4  [{'label': 'display', 'lat': 40.7623254, 'lng'...                370
#
#   location.postalCode location.cc location.city location.state  \
# 0               10016          US      New York             NY
# 1               10065          US      New York             NY
# 2               10065          US      New York             NY
# 3               10019          US      New York             NY
# 4               10019          US      New York             NY
#
#   location.country                          location.formattedAddress  \
# 0    United States  [99 Park Ave (40th St), New York, NY 10016, Un...
# 1    United States  [667 Madison Ave, New York, NY 10065, United S...
# 2    United States  [E65th St (E65th St), New York, NY 10065, Unit...
# 3    United States                [New York, NY 10019, United States]
# 4    United States  [1633 Broadway, New York, NY 10019, United Sta...
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4    579017919

# %%
# keep only columns that include hotel name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in df_hotels.columns if col.startswith('location.')] + ['id']
df_hotels_filtered = df_hotels.loc[:, filtered_columns]

# function that extracts the category of the hotels
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
df_hotels_filtered['categories'] = df_hotels_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
df_hotels_filtered.columns = [column.split('.')[-1] for column in df_hotels_filtered.columns]

pd.DataFrame(df_hotels_filtered)
df_hotels_filtered
# Out:
#                                                  name          categories  \
# 0                         Leading Hotels of the World               Hotel
# 1                              Loews Hotels & Resorts               Hotel
# 2   Hotels Cheap Booking Worldwide | أرخص حجوزات ا...       Travel Agency
# 3                      Starwood Hotels Global Offices            Building
# 4                                      Triumph Hotels  Real Estate Office
# 5             Starwood Hotels NYC Metro Market Office              Office
# 6                                 Compass Hotels Club               Hotel
# 7                               Orient Express Hotels                None
# 8                 Starwood Hotels Global Sales Office              Office
# 9                          Le Soleil Executive Hotels               Hotel
# 10              Hyatt Hotels Corporation Global Sales              Office
# 11                                  Apple Core Hotels               Hotel
# 12               CARINO Hotels & Resorts Worldwide HQ              Office
# 13                Even Hotels New York - Midtown East               Hotel
# 14                        Leading Hotels of the World      General Travel
# 15                     Orient Express Hotels, Ltd. HQ                None
# 16                                       Loews Hotels               Hotel
# 17         Concorde Hotels & Resorts Corporate Office              Office
# 18                                      Lowe’s Hotels              Office
# 19                                   Grandlife Hotels              Office
# 20                    The Pod Hotel's Rooftop Terrace           Roof Deck
# 21                               Accor Hotels N.A. HQ              Office
# 22                          Millennium Broadway Hotel               Hotel
# 23                                       D Pet Hotels         Pet Service
# 24                               D Pet Hotels Chelsea         Pet Service
# 25                                   Sofitel New York               Hotel
# 26                                     Hotel St James               Hotel
# 27                                 Hotels Curated NYC          Public Art
# 28                                          Hotels AB                None
# 29                                       Faena Hotels              Office
#
#                               address  \
# 0                         99 Park Ave
# 1                     667 Madison Ave
# 2                            E65th St
# 3                                 NaN
# 4                       1633 Broadway
# 5                                 NaN
# 6                        40 W 45th St
# 7   1114 Avenue of the Americas Fl 38
# 8                         650 5th Ave
# 9                        38 W 36th St
# 10                        3 E 41st St
# 11            15 W 39th St, 2nd Floor
# 12               230 Park Ave Rm 1000
# 13                      221 E 44th St
# 14                  485 Lexington Ave
# 15                    555 Madison Ave
# 16                    667 Madison Ave
# 17                         1 Penn Plz
# 18                    655 Madison Ave
# 19                     310 W Broadway
# 20                      230 E 51st St
# 21                         3 Park Ave
# 22                      145 W 44th St
# 23                      104 W 27th St
# 24                      104 W 27th St
# 25                       45 W 44th St
# 26                      109 W 45th St
# 27                                NaN
# 28                        23 E 4th St
# 29                      420 W 14th St
#
#                                 crossStreet        lat        lng  \
# 0                                   40th St  40.750323 -73.978408
# 1                                       NaN  40.764518 -73.970214
# 2                                  E65th St  40.766867 -73.967246
# 3                                       NaN  40.760236 -73.981123
# 4                                       NaN  40.762325 -73.984688
# 5                                       NaN  40.762448 -73.981058
# 6                                       NaN  40.758463 -73.979025
# 7                                   42nd St  40.754766 -73.983210
# 8                                       NaN  40.759982 -73.976815
# 9                                       NaN  40.750407 -73.985440
# 10                          Madison and 5th  40.752648 -73.980922
# 11                                      NaN  40.752298 -73.983416
# 12  (Bet 45th and 46th Streets on Park Ave)  40.755238 -73.976469
# 13                     btwn 3rd and 2nd Ave  40.751835 -73.972376
# 14                                  47th St  40.753867 -73.973675
# 15                             E55th Street  40.761340 -73.972830
# 16                                     61st  40.754571 -73.936060
# 17                        btw Fashion & 8th  40.750904 -73.992332
# 18                                      NaN  40.762854 -73.970931
# 19                                      NaN  40.722032 -74.004670
# 20                        Between 2nd & 3rd  40.755481 -73.969340
# 21                                 E 34 St.  40.746933 -73.981339
# 22                              at Broadway  40.757073 -73.984800
# 23                                      NaN  40.745630 -73.991434
# 24                                      NaN  40.745545 -73.991565
# 25                               at 6th Ave  40.755787 -73.981762
# 26                    btw 7th Ave & 6th Ave  40.757038 -73.983326
# 27                                      NaN  40.739395 -74.006986
# 28                                Lafayette  40.727819 -73.992573
# 29                                      NaN  40.741636 -74.006627
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 40.750323, 'lng':...      1094      10016
# 1   [{'label': 'display', 'lat': 40.76451788, 'lng...      1352      10065
# 2   [{'label': 'display', 'lat': 40.76686723801730...      1698      10065
# 3   [{'label': 'display', 'lat': 40.76023595473447...       316      10019
# 4   [{'label': 'display', 'lat': 40.7623254, 'lng'...       370      10019
# 5   [{'label': 'display', 'lat': 40.76244776685527...       481        NaN
# 6   [{'label': 'display', 'lat': 40.758463, 'lng':...       465      10036
# 7   [{'label': 'display', 'lat': 40.75476586818695...       483      10036
# 8   [{'label': 'display', 'lat': 40.75998205059780...       657      10019
# 9   [{'label': 'display', 'lat': 40.75040662233482...       959      10018
# 10  [{'label': 'display', 'lat': 40.75264813617888...       768      10017
# 11  [{'label': 'display', 'lat': 40.75229799999999...       751      10018
# 12  [{'label': 'display', 'lat': 40.75523776716017...       796      10169
# 13  [{'label': 'display', 'lat': 40.7518354, 'lng'...      1296      10017
# 14  [{'label': 'display', 'lat': 40.75386722988113...      1076      10017
# 15  [{'label': 'display', 'lat': 40.76133983707058...      1017      10022
# 16                                                NaN      4114      10065
# 17  [{'label': 'display', 'lat': 40.75090427981508...      1117      10119
# 18  [{'label': 'display', 'lat': 40.762854, 'lng':...      1221      10065
# 19  [{'label': 'display', 'lat': 40.72203190438143...      4453      10013
# 20  [{'label': 'display', 'lat': 40.75548117470931...      1336      10022
# 21  [{'label': 'display', 'lat': 40.74693298339844...      1369      10016
# 22  [{'label': 'display', 'lat': 40.757073, 'lng':...       215      10036
# 23  [{'label': 'display', 'lat': 40.74562953111238...      1599      10001
# 24  [{'label': 'display', 'lat': 40.745545, 'lng':...      1611      10001
# 25  [{'label': 'display', 'lat': 40.75578722233005...       425      10036
# 26  [{'label': 'display', 'lat': 40.75703847698455...       239      10036
# 27  [{'label': 'display', 'lat': 40.739395, 'lng':...      2891        NaN
# 28  [{'label': 'display', 'lat': 40.72781900000000...      3537      10003
# 29  [{'label': 'display', 'lat': 40.74163602691379...      2686      10014
#
#     cc      city     state        country  \
# 0   US  New York        NY  United States
# 1   US  New York        NY  United States
# 2   US  New York        NY  United States
# 3   US  New York        NY  United States
# 4   US  New York        NY  United States
# 5   US       NaN  New York  United States
# 6   US  New York        NY  United States
# 7   US  New York        NY  United States
# 8   US  New York        NY  United States
# 9   US  New York        NY  United States
# 10  US  New York        NY  United States
# 11  US  New York        NY  United States
# 12  US  New York        NY  United States
# 13  US  New York        NY  United States
# 14  US  New York        NY  United States
# 15  US  New York        NY  United States
# 16  US  New York        NY  United States
# 17  US  New York        NY  United States
# 18  US  New York        NY  United States
# 19  US  New York        NY  United States
# 20  US  New York        NY  United States
# 21  US  New York        NY  United States
# 22  US  New York        NY  United States
# 23  US  New York        NY  United States
# 24  US  New York        NY  United States
# 25  US  New York        NY  United States
# 26  US  New York        NY  United States
# 27  US  New York        NY  United States
# 28  US  New York        NY  United States
# 29  US  New York        NY  United States
#
#                                      formattedAddress  \
# 0   [99 Park Ave (40th St), New York, NY 10016, Un...
# 1   [667 Madison Ave, New York, NY 10065, United S...
# 2   [E65th St (E65th St), New York, NY 10065, Unit...
# 3                 [New York, NY 10019, United States]
# 4   [1633 Broadway, New York, NY 10019, United Sta...
# 5                           [New York, United States]
# 6   [40 W 45th St, New York, NY 10036, United States]
# 7   [1114 Avenue of the Americas Fl 38 (42nd St), ...
# 8    [650 5th Ave, New York, NY 10019, United States]
# 9   [38 W 36th St, New York, NY 10018, United States]
# 10  [3 E 41st St (Madison and 5th), New York, NY 1...
# 11  [15 W 39th St, 2nd Floor, New York, NY 10018, ...
# 12  [230 Park Ave Rm 1000 ((Bet 45th and 46th Stre...
# 13  [221 E 44th St (btwn 3rd and 2nd Ave), New Yor...
# 14  [485 Lexington Ave (47th St), New York, NY 100...
# 15  [555 Madison Ave (E55th Street), New York, NY ...
# 16  [667 Madison Ave (61st), New York, NY 10065, U...
# 17  [1 Penn Plz (btw Fashion & 8th), New York, NY ...
# 18  [655 Madison Ave, New York, NY 10065, United S...
# 19  [310 W Broadway, New York, NY 10013, United St...
# 20  [230 E 51st St (Between 2nd & 3rd), New York, ...
# 21  [3 Park Ave (E 34 St.), New York, NY 10016, Un...
# 22  [145 W 44th St (at Broadway), New York, NY 100...
# 23  [104 W 27th St, New York, NY 10001, United Sta...
# 24  [104 W 27th St, New York, NY 10001, United Sta...
# 25  [45 W 44th St (at 6th Ave), New York, NY 10036...
# 26  [109 W 45th St (btw 7th Ave & 6th Ave), New Yo...
# 27                      [New York, NY, United States]
# 28  [23 E 4th St (Lafayette), New York, NY 10003, ...
# 29  [420 W 14th St, New York, NY 10014, United Sta...
#
#                           id
# 0   4cadd6b9d1f8b60cf41d72c6
# 1   5147898ce4b02dd3371672de
# 2   5915de0bda5ede1d81c935b1
# 3   51349950e4b07cce559b7ccf
# 4   5690195e498edb833ddabfac
# 5   4e56ae3eb993a739822887b4
# 6   4e00b2ea1f6ef39c2940bcbb
# 7   4c5062532a73c928161e6dd2
# 8   4c20bb264d4a20a1a7259b70
# 9   550c5e1b498ec8c459b165c6
# 10  512654d8e4b0c83f4d8a92b0
# 11  4da7a1b8a86e68edb7cc3419
# 12  4c4df46792b6a593beb7216f
# 13  5841facedb6cd606fead9b04
# 14  5061c80ee4b08374aa9b8291
# 15  4f0ee72ee4b0575169a8563a
# 16  52f27359498e7163b8ef6279
# 17  4c93981c533aa0933254b745
# 18  5afde00d029a55002c04aa94
# 19  4d4711197e2e5481b9127a8f
# 20  4ca39f685720b1f7515633ef
# 21  528512c611d20598768a6d4c
# 22  4a0215c6f964a5202a711fe3
# 23  50637e02e4b06a6415f2af29
# 24  51d5e28a498e14890713c77b
# 25  4b4e71caf964a520f8ed26e3
# 26  4b4ba81df964a5200ba326e3
# 27  524f040e11d25521010a001a
# 28  4c23c942a852c9288510e26c
# 29  504f6f44e4b06a753d408617

# %%
df_hotels_filtered = df_hotels_filtered[df_hotels_filtered.categories.isin(['Hotel', 'Office'])]
df_hotels_filtered.categories = 'Hotel'
df_hotels_filtered.reset_index(drop=True, inplace=True)
df_hotels_filtered
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#                                           name categories  \
# 0                  Leading Hotels of the World      Hotel
# 1                       Loews Hotels & Resorts      Hotel
# 2      Starwood Hotels NYC Metro Market Office      Hotel
# 3                          Compass Hotels Club      Hotel
# 4          Starwood Hotels Global Sales Office      Hotel
# 5                   Le Soleil Executive Hotels      Hotel
# 6        Hyatt Hotels Corporation Global Sales      Hotel
# 7                            Apple Core Hotels      Hotel
# 8         CARINO Hotels & Resorts Worldwide HQ      Hotel
# 9          Even Hotels New York - Midtown East      Hotel
# 10                                Loews Hotels      Hotel
# 11  Concorde Hotels & Resorts Corporate Office      Hotel
# 12                               Lowe’s Hotels      Hotel
# 13                            Grandlife Hotels      Hotel
# 14                        Accor Hotels N.A. HQ      Hotel
# 15                   Millennium Broadway Hotel      Hotel
# 16                            Sofitel New York      Hotel
# 17                              Hotel St James      Hotel
# 18                                Faena Hotels      Hotel
#
#                     address                              crossStreet  \
# 0               99 Park Ave                                  40th St
# 1           667 Madison Ave                                      NaN
# 2                       NaN                                      NaN
# 3              40 W 45th St                                      NaN
# 4               650 5th Ave                                      NaN
# 5              38 W 36th St                                      NaN
# 6               3 E 41st St                          Madison and 5th
# 7   15 W 39th St, 2nd Floor                                      NaN
# 8      230 Park Ave Rm 1000  (Bet 45th and 46th Streets on Park Ave)
# 9             221 E 44th St                     btwn 3rd and 2nd Ave
# 10          667 Madison Ave                                     61st
# 11               1 Penn Plz                        btw Fashion & 8th
# 12          655 Madison Ave                                      NaN
# 13           310 W Broadway                                      NaN
# 14               3 Park Ave                                 E 34 St.
# 15            145 W 44th St                              at Broadway
# 16             45 W 44th St                               at 6th Ave
# 17            109 W 45th St                    btw 7th Ave & 6th Ave
# 18            420 W 14th St                                      NaN
#
#           lat        lng                                     labeledLatLngs  \
# 0   40.750323 -73.978408  [{'label': 'display', 'lat': 40.750323, 'lng':...
# 1   40.764518 -73.970214  [{'label': 'display', 'lat': 40.76451788, 'lng...
# 2   40.762448 -73.981058  [{'label': 'display', 'lat': 40.76244776685527...
# 3   40.758463 -73.979025  [{'label': 'display', 'lat': 40.758463, 'lng':...
# 4   40.759982 -73.976815  [{'label': 'display', 'lat': 40.75998205059780...
# 5   40.750407 -73.985440  [{'label': 'display', 'lat': 40.75040662233482...
# 6   40.752648 -73.980922  [{'label': 'display', 'lat': 40.75264813617888...
# 7   40.752298 -73.983416  [{'label': 'display', 'lat': 40.75229799999999...
# 8   40.755238 -73.976469  [{'label': 'display', 'lat': 40.75523776716017...
# 9   40.751835 -73.972376  [{'label': 'display', 'lat': 40.7518354, 'lng'...
# 10  40.754571 -73.936060                                                NaN
# 11  40.750904 -73.992332  [{'label': 'display', 'lat': 40.75090427981508...
# 12  40.762854 -73.970931  [{'label': 'display', 'lat': 40.762854, 'lng':...
# 13  40.722032 -74.004670  [{'label': 'display', 'lat': 40.72203190438143...
# 14  40.746933 -73.981339  [{'label': 'display', 'lat': 40.74693298339844...
# 15  40.757073 -73.984800  [{'label': 'display', 'lat': 40.757073, 'lng':...
# 16  40.755787 -73.981762  [{'label': 'display', 'lat': 40.75578722233005...
# 17  40.757038 -73.983326  [{'label': 'display', 'lat': 40.75703847698455...
# 18  40.741636 -74.006627  [{'label': 'display', 'lat': 40.74163602691379...
#
#     distance postalCode  cc      city     state        country  \
# 0       1094      10016  US  New York        NY  United States
# 1       1352      10065  US  New York        NY  United States
# 2        481        NaN  US       NaN  New York  United States
# 3        465      10036  US  New York        NY  United States
# 4        657      10019  US  New York        NY  United States
# 5        959      10018  US  New York        NY  United States
# 6        768      10017  US  New York        NY  United States
# 7        751      10018  US  New York        NY  United States
# 8        796      10169  US  New York        NY  United States
# 9       1296      10017  US  New York        NY  United States
# 10      4114      10065  US  New York        NY  United States
# 11      1117      10119  US  New York        NY  United States
# 12      1221      10065  US  New York        NY  United States
# 13      4453      10013  US  New York        NY  United States
# 14      1369      10016  US  New York        NY  United States
# 15       215      10036  US  New York        NY  United States
# 16       425      10036  US  New York        NY  United States
# 17       239      10036  US  New York        NY  United States
# 18      2686      10014  US  New York        NY  United States
#
#                                      formattedAddress  \
# 0   [99 Park Ave (40th St), New York, NY 10016, Un...
# 1   [667 Madison Ave, New York, NY 10065, United S...
# 2                           [New York, United States]
# 3   [40 W 45th St, New York, NY 10036, United States]
# 4    [650 5th Ave, New York, NY 10019, United States]
# 5   [38 W 36th St, New York, NY 10018, United States]
# 6   [3 E 41st St (Madison and 5th), New York, NY 1...
# 7   [15 W 39th St, 2nd Floor, New York, NY 10018, ...
# 8   [230 Park Ave Rm 1000 ((Bet 45th and 46th Stre...
# 9   [221 E 44th St (btwn 3rd and 2nd Ave), New Yor...
# 10  [667 Madison Ave (61st), New York, NY 10065, U...
# 11  [1 Penn Plz (btw Fashion & 8th), New York, NY ...
# 12  [655 Madison Ave, New York, NY 10065, United S...
# 13  [310 W Broadway, New York, NY 10013, United St...
# 14  [3 Park Ave (E 34 St.), New York, NY 10016, Un...
# 15  [145 W 44th St (at Broadway), New York, NY 100...
# 16  [45 W 44th St (at 6th Ave), New York, NY 10036...
# 17  [109 W 45th St (btw 7th Ave & 6th Ave), New Yo...
# 18  [420 W 14th St, New York, NY 10014, United Sta...
#
#                           id
# 0   4cadd6b9d1f8b60cf41d72c6
# 1   5147898ce4b02dd3371672de
# 2   4e56ae3eb993a739822887b4
# 3   4e00b2ea1f6ef39c2940bcbb
# 4   4c20bb264d4a20a1a7259b70
# 5   550c5e1b498ec8c459b165c6
# 6   512654d8e4b0c83f4d8a92b0
# 7   4da7a1b8a86e68edb7cc3419
# 8   4c4df46792b6a593beb7216f
# 9   5841facedb6cd606fead9b04
# 10  52f27359498e7163b8ef6279
# 11  4c93981c533aa0933254b745
# 12  5afde00d029a55002c04aa94
# 13  4d4711197e2e5481b9127a8f
# 14  528512c611d20598768a6d4c
# 15  4a0215c6f964a5202a711fe3
# 16  4b4e71caf964a520f8ed26e3
# 17  4b4ba81df964a5200ba326e3
# 18  504f6f44e4b06a753d408617

# %%
df_hotels_filtered.drop(['crossStreet', 'labeledLatLngs', 'postalCode', 'state', 'country', 'city'], axis=1, inplace=True)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_hotels_filtered
# Out:
#                                           name categories  \
# 0                  Leading Hotels of the World      Hotel
# 1                       Loews Hotels & Resorts      Hotel
# 2      Starwood Hotels NYC Metro Market Office      Hotel
# 3                          Compass Hotels Club      Hotel
# 4          Starwood Hotels Global Sales Office      Hotel
# 5                   Le Soleil Executive Hotels      Hotel
# 6        Hyatt Hotels Corporation Global Sales      Hotel
# 7                            Apple Core Hotels      Hotel
# 8         CARINO Hotels & Resorts Worldwide HQ      Hotel
# 9          Even Hotels New York - Midtown East      Hotel
# 10                                Loews Hotels      Hotel
# 11  Concorde Hotels & Resorts Corporate Office      Hotel
# 12                               Lowe’s Hotels      Hotel
# 13                            Grandlife Hotels      Hotel
# 14                        Accor Hotels N.A. HQ      Hotel
# 15                   Millennium Broadway Hotel      Hotel
# 16                            Sofitel New York      Hotel
# 17                              Hotel St James      Hotel
# 18                                Faena Hotels      Hotel
#
#                     address        lat        lng  distance  cc  \
# 0               99 Park Ave  40.750323 -73.978408      1094  US
# 1           667 Madison Ave  40.764518 -73.970214      1352  US
# 2                       NaN  40.762448 -73.981058       481  US
# 3              40 W 45th St  40.758463 -73.979025       465  US
# 4               650 5th Ave  40.759982 -73.976815       657  US
# 5              38 W 36th St  40.750407 -73.985440       959  US
# 6               3 E 41st St  40.752648 -73.980922       768  US
# 7   15 W 39th St, 2nd Floor  40.752298 -73.983416       751  US
# 8      230 Park Ave Rm 1000  40.755238 -73.976469       796  US
# 9             221 E 44th St  40.751835 -73.972376      1296  US
# 10          667 Madison Ave  40.754571 -73.936060      4114  US
# 11               1 Penn Plz  40.750904 -73.992332      1117  US
# 12          655 Madison Ave  40.762854 -73.970931      1221  US
# 13           310 W Broadway  40.722032 -74.004670      4453  US
# 14               3 Park Ave  40.746933 -73.981339      1369  US
# 15            145 W 44th St  40.757073 -73.984800       215  US
# 16             45 W 44th St  40.755787 -73.981762       425  US
# 17            109 W 45th St  40.757038 -73.983326       239  US
# 18            420 W 14th St  40.741636 -74.006627      2686  US
#
#                                      formattedAddress  \
# 0   [99 Park Ave (40th St), New York, NY 10016, Un...
# 1   [667 Madison Ave, New York, NY 10065, United S...
# 2                           [New York, United States]
# 3   [40 W 45th St, New York, NY 10036, United States]
# 4    [650 5th Ave, New York, NY 10019, United States]
# 5   [38 W 36th St, New York, NY 10018, United States]
# 6   [3 E 41st St (Madison and 5th), New York, NY 1...
# 7   [15 W 39th St, 2nd Floor, New York, NY 10018, ...
# 8   [230 Park Ave Rm 1000 ((Bet 45th and 46th Stre...
# 9   [221 E 44th St (btwn 3rd and 2nd Ave), New Yor...
# 10  [667 Madison Ave (61st), New York, NY 10065, U...
# 11  [1 Penn Plz (btw Fashion & 8th), New York, NY ...
# 12  [655 Madison Ave, New York, NY 10065, United S...
# 13  [310 W Broadway, New York, NY 10013, United St...
# 14  [3 Park Ave (E 34 St.), New York, NY 10016, Un...
# 15  [145 W 44th St (at Broadway), New York, NY 100...
# 16  [45 W 44th St (at 6th Ave), New York, NY 10036...
# 17  [109 W 45th St (btw 7th Ave & 6th Ave), New Yo...
# 18  [420 W 14th St, New York, NY 10014, United Sta...
#
#                           id
# 0   4cadd6b9d1f8b60cf41d72c6
# 1   5147898ce4b02dd3371672de
# 2   4e56ae3eb993a739822887b4
# 3   4e00b2ea1f6ef39c2940bcbb
# 4   4c20bb264d4a20a1a7259b70
# 5   550c5e1b498ec8c459b165c6
# 6   512654d8e4b0c83f4d8a92b0
# 7   4da7a1b8a86e68edb7cc3419
# 8   4c4df46792b6a593beb7216f
# 9   5841facedb6cd606fead9b04
# 10  52f27359498e7163b8ef6279
# 11  4c93981c533aa0933254b745
# 12  5afde00d029a55002c04aa94
# 13  4d4711197e2e5481b9127a8f
# 14  528512c611d20598768a6d4c
# 15  4a0215c6f964a5202a711fe3
# 16  4b4e71caf964a520f8ed26e3
# 17  4b4ba81df964a5200ba326e3
# 18  504f6f44e4b06a753d408617

# %%
allhotels_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around the New York City

#add outline of theatre district
coordinates = [
    [40.764346,-73.983779],
    [40.759103,-73.983090],
    [40.755484,-73.988302],
    [40.759253,-73.989211],
    [40.764346,-73.983779]
]

my_PolyLine=folium.PolyLine(locations=coordinates,weight=5)
allhotels_map.add_child(my_PolyLine)

# add the Hotels as blue circle markers
for lat, lng, label in zip(df_hotels_filtered.lat, df_hotels_filtered.lng, df_hotels_filtered.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(allhotels_map)

# display map
allhotels_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
